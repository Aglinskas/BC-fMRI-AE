# %%
pwd
# Out:
# '/mmfs1/data/aglinska/BC-fMRI-AE/Data'

# %%
import numpy as np
import pandas as pd

# %%
np.load('cmats_SFARI_S121.npz')['cmats'].shape
# Out:
# (121, 51, 51)

# %%
df = pd.read_csv('sfari_df_S121.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1   SFARI_ID  BIDS_ID  site  age_years  \
# 0             0             0   14702.x3  sub-001    60          8
# 1             1             2  14705.x14  sub-003    50         34
# 2             2             5  14714.x18  sub-006    60         21
# 3             3             8  14723.x17  sub-009    60          5
# 4             5            11  14725.x48  sub-012    60         35
# ..          ...           ...        ...      ...   ...        ...
# 116         128           200   15048.x1  sub-201    50         13
# 117         130           202   15060.x1  sub-203    50         28
# 118         131           204   15071.x1  sub-205    60         28
# 119         132           206   15083.x5  sub-207    50         12
# 120         133           207   15090.x1  sub-208    50         14
#
#      latest_clinical_asd_dx svip_diagnosis_m1           family_type  \
# 0                     False   non-spectrum-dx          16p-deletion
# ...

# %%
df.groupby(by=['family_type']).count()
# Out:
#                       Unnamed: 0  Unnamed: 0.1  SFARI_ID  BIDS_ID  site  \
# family_type
# 16p-deletion                  20            20        20       20    20
# 16p-duplication               22            22        22       22    22
# 16p-triplication               2             2         2        2     2
# 1q-deletion                    6             6         6        6     6
# 1q-duplication                 2             2         2        2     2
# non-familial-control          69            69        69       69    69
#
#                       age_years  latest_clinical_asd_dx  svip_diagnosis_m1  \
# family_type
# 16p-deletion                 20                      20                 20
# 16p-duplication              22                      22                 22
# 16p-triplication              2                       2                  2
# 1q-deletion                   6                       6                  6
# ...
