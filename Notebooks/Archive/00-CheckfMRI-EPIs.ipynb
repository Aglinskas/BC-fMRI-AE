# %%
import ants
import numpy as np
import os

# %%
indir1 = '/mmfs1/data/aglinska/data/ABIDE/Derivatives/cpac_nofilt_global/'
conts = [cont for cont in os.listdir(indir1) if 'sub-' in cont]
conts.sort()

# %%
# ims = list()
# for s in np.arange(0,len(conts),100):
#     sub = conts[s]
#     fn = os.path.join(indir1,sub,'ses-1','func',f'{sub}_ses-1_mean.nii.gz')
#     im = ants.image_read(fn)
#     im.plot_ortho(flat=True,title=f'{sub} | {im.shape}')
#     ims.append(im)

# %%
ims[10].plot_ortho(ims[11],overlay_alpha=.3,flat=True)

# %%
indir1 = '/mmfs1/data/aglinska/data/ABIDE2/Derivatives/test/fmriprep/'
conts = [cont for cont in os.listdir(indir1) if all((cont.startswith('sub-'),os.path.isdir(os.path.join(indir1,cont))))]
conts.sort()
print(len(conts))
# Out:
# 88

# %%
ims2 = list()
for s in np.arange(0,len(conts),1):
    try:
        sub = conts[s]
        #fn = os.path.join(indir1,sub,'ses-1','func',f'{sub}_ses-1_task-rest_run-1_space-MNI152NLin2009cAsym_boldref.nii.gz')
        fn_mask = os.path.join(indir1,sub,'ses-1','func',f'{sub}_ses-1_task-rest_run-1_space-MNI152NLin2009cAsym_boldref.nii.gz')
        im = ants.image_read(fn)
        #im.plot_ortho(flat=True,title=f'{sub} | {im.shape}')
        ims2.append(im)
    except:
        pass

# %%
len(ims2)
# Out:
# 0

# %%
ims2[10].plot_ortho(ims[10],flat=True,overlay_alpha=.3)

# %%
#_boldref.nii.gz
# Out:
# []
