# %%
# !aws s3 ls s3://fcp-indi/data/Projects/ --no-sign-request
# Out:
#                            PRE ABIDE/
#                            PRE ABIDE2/
#                            PRE ABIDE_Initiative/
#                            PRE ACPI/
#                            PRE ADHD200/
#                            PRE BASC/
#                            PRE BGSP/
#                            PRE CC_ME/
#                            PRE CORR/
#                            PRE CPAC_Regression_Test/
#                            PRE EEG_Eyetracking_CMI_data/
#                            PRE FCON1000/
#                            PRE HBN/
#                            PRE HBNSSI/
#                            PRE HBN_EEG_MRI/
#                            PRE INDI/
#                            PRE RocklandSample/
#                            PRE narratives/

# %%
# !aws s3 ls s3://fcp-indi/data/Projects/ABIDE2/ --no-sign-request
# Out:
#                            PRE ABIDEII-GU_1/
#                            PRE Outputs/
#                            PRE RawData/
# 2016-11-29 15:01:02          0

# %%
# !aws s3 ls s3://fcp-indi/data/Projects/ABIDE/ --no-sign-request
# Out:
#                            PRE Derivatives/
#                            PRE Outputs/
#                            PRE PhenotypicData/
#                            PRE RawData/
#                            PRE RawDataBIDS/
#                            PRE Resources/
# 2016-12-15 19:51:28     175924 Phenotypic_V1_0b.csv
# 2016-12-15 19:51:28     603964 Phenotypic_V1_0b_preprocessed.csv
# 2016-12-15 19:51:28     449443 Phenotypic_V1_0b_preprocessed1.csv
# 2018-05-23 14:53:47      12426 cpac_data_config.yml
# 2018-05-23 14:53:48       4354 cpac_pipeline_config.yml

# %%
# !aws s3 ls s3://fcp-indi/data/Projects/ABIDE/Outputs/ --no-sign-request
# Out:
#                            PRE ants/
#                            PRE ccs/
#                            PRE civet/
#                            PRE cpac/
#                            PRE denoise/
#                            PRE dparsf/
#                            PRE fmriprep/
#                            PRE freesurfer/
#                            PRE mindboggle_swf/
#                            PRE mriqc/
#                            PRE niak/
#                            PRE qap/
#                            PRE testing/

# %%
# aws s3 sync s3://fcp-indi/data/Projects/ABIDE/PhenotypicData/ ./data/ABIDE/PhenotypicData/ --no-sign-request
# aws s3 sync s3://fcp-indi/data/Projects/ABIDE/Phenotypic_V1_0b.csv ./data/ABIDE/Phenotypic_V1_0b.csv --no-sign-request
# aws s3 sync s3://fcp-indi/data/Projects/ABIDE/Phenotypic_V1_0b_preprocessed1.csv ./data/ABIDE/Phenotypic_V1_0b_preprocessed1.csv --no-sign-request

# %%
# !aws s3 sync s3://fcp-indi/data/Projects/ABIDE/PhenotypicData/ ./data/ABIDE/PhenotypicData/ --no-sign-request

# %%
# !aws s3 help
# Out:
# S3()                                                                      S3()
#
#
#
# NAME
#        s3 -
#
# DESCRIPTION
#        This  section  explains  prominent concepts and notations in the set of
#        high-level S3 commands provided.
#
#    Path Argument Type
#        Whenever using a command, at least one path argument must be specified.
#        There are two types of path arguments: LocalPath and S3Uri.
#
#        LocalPath: represents the path of a local file or directory.  It can be
#        written as an absolute path or relative path.
#
#        S3Uri: represents the location of a S3 object, prefix, or bucket.  This
#        must  be  written in the form s3://mybucket/mykey where mybucket is the
#        specified S3 bucket, mykey is the specified S3 key.  The path  argument
#        must  begin with s3:// in order to denote that the path argument refers
#        to a S3 object. Note that prefixes are separated  by  forward  slashes.
# ...
