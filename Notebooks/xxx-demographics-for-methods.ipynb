# %%
from datetime import datetime
import pandas as pd

# %%
df = pd.read_csv('../Data/comb_df.csv')
df
# Out:
#       Unnamed: 0  participant_id  diag    age  sex    fiq            site  \
# 0              0           50002     1  16.77    1  103.0              13
# 1              2           50004     1  19.09    1  113.0              13
# 2              3           50005     1  13.73    2  119.0              13
# 3              4           50006     1  13.37    1  109.0              13
# 4              9           50011     1  16.93    1  111.0              13
# ...          ...             ...   ...    ...  ...    ...             ...
# 1497         746           30163     2   8.00    2  136.0  ABIDEII-OHSU_1
# 1498         747           30164     2  10.00    2  115.0  ABIDEII-OHSU_1
# 1499         748           30165     2  12.00    2  120.0  ABIDEII-OHSU_1
# 1500         749           30166     2  10.00    2  112.0  ABIDEII-OHSU_1
# 1501         750           30167     2  14.00    2  100.0  ABIDEII-OHSU_1
#
#       DSMIV  ados_total  ados_social  ados_comm  ados_rrb   dataset
# ...

# %%
print((df['diag']==1).sum())
print((df['diag']==2).sum())
# Out:
# 661
# 841

# %%
((df['diag'].values==1) * (df['sex'].values==2)).sum()
# Out:
# 75

# %%
((df['diag'].values==2) * (df['sex'].values==2)).sum()
# Out:
# 205

# %%
asd_ages = df.iloc[df['diag'].values==1]['age'].values
(asd_ages.min().round(2),asd_ages.max().round(2),asd_ages.mean().round(2))
# Out:
# (5.13, 58.0, 16.72)

# %%
td_ages = df.iloc[df['diag'].values==2]['age'].values
(td_ages.min().round(2),td_ages.max().round(2),td_ages.mean().round(2))
# Out:
# (5.89, 64.0, 16.06)

# %%
dfs = pd.read_csv('../Data/sfari_df.csv')
dfs
# Out:
#      Unnamed: 0   SFARI_ID  BIDS_ID  site  age_years  latest_clinical_asd_dx  \
# 0             0   14702.x3  sub-001    60          8                   False
# 1             2  14705.x14  sub-003    50         34                   False
# 2             5  14714.x18  sub-006    60         21                   False
# 3             8  14723.x17  sub-009    60          5                   False
# 4            10  14725.x46  sub-011    50         10                   False
# ..          ...        ...      ...   ...        ...                     ...
# 129         201   15057.x1  sub-202    50         62                   False
# 130         202   15060.x1  sub-203    50         28                   False
# 131         204   15071.x1  sub-205    60         28                   False
# 132         206   15083.x5  sub-207    50         12                   False
# 133         207   15090.x1  sub-208    50         14                   False
#
# ...
