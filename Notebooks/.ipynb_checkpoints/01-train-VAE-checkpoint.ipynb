# %%
pwd
# Out:
# '/mmfs1/data/aglinska/BC-fMRI-AE/Notebooks'

# %%
whos
# Out:
# Interactive namespace is empty.

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('../Data/ABIDE_df2.csv')
df = df.iloc[~pd.isna(df['bids_folder']).values]
data_dir = '../Assets/fc_mats/'

# %%
files = [file for file in os.listdir(data_dir) if file.endswith('.npz')]
files.sort()

# %%
has_file = np.array([os.path.exists(os.path.join(data_dir,sub + '.npz')) for sub in df['bids_folder'].values])
print(has_file.mean())

assert has_file.mean()==1.0, 'fuck'
# Out:
# 1.0

# %%
# LOAD DATA
n_subs = 200
data = np.zeros((n_subs,48, 48, 48, 51))
#for s in tqdm(range(len(df))):
for s in tqdm(range(n_subs),position=0, leave=True):
    sub = df['bids_folder'].values[s]
    datum = np.load(os.path.join(data_dir,sub + '.npz'))['data']
    data[s,:,:,:,:] = datum
# Out:
# 100%|██████████| 200/200 [00:28<00:00,  7.02it/s]

# %%
data.shape
# Out:
# (200, 48, 48, 48, 51)

# %%
plt.imshow(data[10,:,:,20,1])

# %%
# %time
from helper_funcs import *
from importlib import reload
import make_models
reload(make_models)
del make_models
from make_models import *

from IPython import display
import sys
from sklearn.decomposition import PCA
import seaborn as sns
# Out:
# CPU times: user 10 µs, sys: 3 µs, total: 13 µs
# Wall time: 28.6 µs

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
data_batch = data[0:32,:,:,:,:]

# %%
encoder, decoder, vae = get_MRI_VAE_3D(input_shape=(48,48,48,51),
                   latent_dim = 8, 
                   batch_size = 32, 
                   disentangle = True, 
                   gamma = 1,
                   kernel_size = 3,
                   filters = 8,
                   intermediate_dim = 128,
                   nlayers = 2,
                   learning_rate=0.001)

# %%
data[np.isnan(data)]=0

# %%
data[abs(data)<1e-4]=0

# %%
def norm(mat):
    normed = (mat - mat.min()) / (mat.max()-mat.min())
    return normed

# %%
data_normed = np.array([norm(data[i,:,:,:,:]) for i in range(data.shape[0])])
# Out:
# <ipython-input-229-fcb39f7fda83>:2: RuntimeWarning: invalid value encountered in true_divide
#   normed = (mat - mat.min()) / (mat.max()-mat.min())

# %%
data_normed[np.isnan(data_normed)]=0

# %%
np.isnan(data_normed).mean()
# Out:
# 0.0

# %%
print(data_normed.min())
print(data_normed.max())
# Out:
# nan
# nan

# %%
loss = list()

# %%
for i in tqdm(range(100),position=0, leave=True):
    data_batch = data_normed[np.random.randint(high=200,low=0,size=32),:,:,:]
    hist = vae.train_on_batch(data_batch)
    assert not np.isnan(hist),'loss is NaN - you f**cked up'
    
    loss.append(hist)
    display.clear_output(wait=True);
    display.display(plt.gcf());
    
    #Organise figure
    ncols = 4;nrows=5
    plt.subplots(nrows,ncols,figsize=(15,15));
    
    # Plot loss
    plt.subplot(nrows,ncols/2,1)
    xs = np.arange(len(loss))+1
    m,b = np.polyfit(xs,loss,deg=1)
    plt.plot(loss)
    plt.plot(xs, m*xs + b)
    plt.title(hist)
    
    plt.subplot(nrows,ncols,5)
    hb = 50
    if len(loss)>hb:
        plot_loss = loss[-hb::]
        xs = np.arange(len(plot_loss))+1
        m,b = np.polyfit(xs,plot_loss,deg=1)
        plt.plot(plot_loss)
        plt.plot(xs, m*xs + b)
        #plt.title(hist)
    plt.title(f'loss last {hb} it')
    
    # Plot recon
    prediction = vae.predict(data_batch)    
    
    plt.subplot(nrows,ncols,3)
    plt.imshow(data_batch[0,:,:,20,0])
    plt.xticks([]);plt.yticks([]);plt.title('actual')
    
    plt.subplot(nrows,ncols,4)
    plt.imshow(prediction[0,:,:,20,0])
    plt.xticks([]);plt.yticks([]);plt.title('predicted')
    
    plt.subplot(nrows,ncols,8)
    plt.hist(prediction[0,:,:,:,0].flatten(),alpha=.5)
    plt.hist(data_batch[0,:,:,:,0].flatten(),alpha=.5)
    plt.legend(['predicted','actual']);plt.title('predicted')
    
    plt.subplot(nrows,ncols,6)
    pc = PCA(n_components=2).fit_transform(encoder.predict(data_batch)[2])
    plt.scatter(pc[:,0],pc[:,1],s=100,alpha=.5);plt.title('batch latent rep. PCA')
    
    plt.subplot(nrows,ncols,7)
    sns.heatmap(np.corrcoef(prediction.reshape(32,-1)),xticklabels=[],yticklabels=[])
    plt.title('batch latent rep. RSA')
    
    plt.tight_layout()
    #sys.stdout.flush()
# Out:
# <ipython-input-261-ec60d5f20e36>:15: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nrows,ncols/2,1)
# <ipython-input-261-ec60d5f20e36>:44: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(nrows,ncols,5)
#  96%|█████████▌| 96/100 [10:32<00:26,  6.58s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-261-ec60d5f20e36> in <module>
#      52
#      53     plt.subplot(nrows,ncols,7)
# ...
